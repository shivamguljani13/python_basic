# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamguljani13/python_basic/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

data= {"name":["rahul","shivam","shubham"],
      "age":[23,24,25],
      "gender":["male","male","male"]
      }
df=pd.DataFrame(data)
print(df)
df
# Out:
#       name  age gender
# 0    rahul   23   male
# 1   shivam   24   male
# 2  shubham   25   male
#       name  age gender
# 0    rahul   23   male
# 1   shivam   24   male
# 2  shubham   25   male

# %% [markdown]
# DataFrame using list

# %%
data = [['John', 25, 'New York'], ['Jane', 30, 'London'], ['Tom', 35, 'Paris']]
df = pd.DataFrame(data, columns=['Name', 'Age', 'City'])
df

# %% [markdown]
# DataFrame using Excel(.xlxs)

# %%
df=pd.read_excel("testdata.xlsx")
df
# Out:
#          NAME  AGE SEX
# 0      shivam   22   M
# 1     shubham   22   M
# 2        yash   21   M
# 3     aashwin   21   M
# 4       varun   21   M
# 5       harsh   22   M
# 6      monika   22   F
# 7   shambhavi   22   F
# 8       komal   22   F
# 9      muskan   23   F
# 10     saumya   22   F

# %% [markdown]
# DataFrame using CSV(Comma Separated Value)

# %%
#df=pd.read_csv("testdata.csv")
df

# %% [markdown]
# DataFrame exploration function

# %%
print("1"+" head() function")
print(df.head(),"\n\n")
print(df.head(2))
print("2"+" tail() function\n")
print(df.tail(),"\n\n")
print(df.tail(2))
print("3"+" describe() function\n")
print(df.describe(),"\n\n" )
print("4"+" info() function\n")
print(df.info(),"\n\n" )
print("5"+" head() function\n")
# Out:
# 1 head() function
#       NAME  AGE SEX
# 0   shivam   22   M
# 1  shubham   22   M
# 2     yash   21   M
# 3  aashwin   21   M
# 4    varun   21   M
#
#
#       NAME  AGE SEX
# 0   shivam   22   M
# 1  shubham   22   M
# 2 tail() function
#
#          NAME  AGE SEX
# 6      monika   22   F
# 7   shambhavi   22   F
# 8       komal   22   F
# 9      muskan   23   F
# 10     saumya   22   F
#
#
#       NAME  AGE SEX
# 9   muskan   23   F
# 10  saumya   22   F
# 3 describe() function
#
#              AGE
# count  11.000000
# mean   21.818182
# std     0.603023
# min    21.000000
# 25%    21.500000
# 50%    22.000000
# 75%    22.000000
# max    23.000000
#
#
# 4 info() function
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    11 non-null     object
#  1   AGE     11 non-null     int64
#  2   SEX     11 non-null     object
# ...

# %%
print(df['AGE'].max())
# Out:
# 23

# %%
df=pd.read_csv("company1.csv")
df
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %% [markdown]
# Data Cleaning

# %%
print(df.duplicated("Name") )
print(df.drop_duplicates("EEID"))
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# dtype: bool
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN

# %%
print(df.isnull()  )
print(df.dropna())
# Out:
#     EEID   Name  gender  salary
# 0  False  False   False    True
# 1  False  False   False   False
# 2  False  False    True   False
# 3  False  False   False   False
# 4  False   True   False   False
# 5  False  False   False    True
# 6  False  False   False   False
#     EEID    Name gender   salary
# 1  EMP02   rohit      M  25000.0
# 3  EMP01  ayushi      F  20000.0
# 6  EMP02   rohit      M  25000.0

# %%
print(df.fillna(method="ffill"),"\n\n")
print(df.fillna(method="bfill"))
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali      M  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05    ayushi      M  25000.0
# 5  EMP06     rohit      M  25000.0
# 6  EMP02     rohit      M  25000.0
#
#
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F  25000.0
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali      F  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05     rohit      M  25000.0
# 5  EMP06     rohit      M  25000.0
# 6  EMP02     rohit      M  25000.0
